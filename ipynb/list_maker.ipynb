# %%
import pandas as pd
from os import getcwd
getcwd()
# Out:
# 'C:\\Users\\Alec\\Documents\\Programming_Resources\\Boot_Camp\\project-04\\CISautoData\\ipynb'

# %%
sedan_df = pd.read_csv('../csv/SEDAN_DATA_CLEAN.csv')
suv_df = pd.read_csv('../csv/SUV_DATA_CLEAN.csv')
trucks_df = pd.read_csv('../csv/PICKUP_DATA_CLEAN.csv')
full_df = pd.read_csv('../csv/all_bodyclass_clean.csv')

# %%
def feature_list_maker(dataframe):
    df_test = dataframe.drop(columns=['msrp','vin','color',])
    #names for each DF/ Model to be trained


    # divide the data
    X = df_test.drop(columns=['ask_price'])
    y = df_test['ask_price']

    # set dummies
    X_dummies = pd.get_dummies(X,drop_first=True)

    # split for test and train
    feature_list = X_dummies.columns.to_list()
    return feature_list

# %%
sedan_feature_list = feature_list_maker(sedan_df)
suv_feature_list = feature_list_maker(suv_df)
trucks_feature_list = feature_list_maker(trucks_df)
full_feature_list = feature_list_maker(full_df)

# %%
suv_feature_list
# Out:
# ['model_ID',
#  'model_year',
#  'mileage',
#  'engine_cylinders',
#  'brand_name_ALFA ROMEO',
#  'brand_name_AUDI',
#  'brand_name_BMW',
#  'brand_name_BUICK',
#  'brand_name_CADILLAC',
#  'brand_name_CHEVROLET',
#  'brand_name_CHRYSLER',
#  'brand_name_DODGE',
#  'brand_name_FIAT',
#  'brand_name_FORD',
#  'brand_name_GMC',
#  'brand_name_HONDA',
#  'brand_name_HUMMER',
#  'brand_name_ISUZU',
#  'brand_name_JAGUAR',
#  'brand_name_JEEP',
#  'brand_name_KIA',
#  'brand_name_LAND ROVER',
#  'brand_name_LEXUS',
#  'brand_name_LINCOLN',
#  'brand_name_MASERATI',
#  'brand_name_MAZDA',
#  'brand_name_MERCEDES-BENZ',
#  'brand_name_MERCURY',
#  'brand_name_MINI',
#  'brand_name_MITSUBISHI',
#  'brand_name_PONTIAC',
#  'brand_name_PORSCHE',
#  'brand_name_SAAB',
#  'brand_name_SATURN',
#  'brand_name_SUBARU',
#  'brand_name_SUZUKI',
#  'brand_name_TOYOTA',
#  'brand_name_VOLKSWAGEN',
#  'brand_name_VOLVO',
#  'model_name_500X',
#  'model_name_9-4x',
#  'model_name_9-7X',
# ...

# %%
trucks_feature_list
# Out:
# ['model_ID',
#  'model_year',
#  'mileage',
#  'engine_cylinders',
#  'brand_name_DODGE',
#  'brand_name_FORD',
#  'brand_name_GMC',
#  'brand_name_HONDA',
#  'brand_name_HUMMER',
#  'brand_name_ISUZU',
#  'brand_name_JEEP',
#  'brand_name_LINCOLN',
#  'brand_name_MAZDA',
#  'brand_name_MITSUBISHI',
#  'brand_name_NISSAN',
#  'brand_name_RAM',
#  'brand_name_TOYOTA',
#  'model_name_2500',
#  'model_name_3500',
#  'model_name_B-Series',
#  'model_name_Blackwood',
#  'model_name_Canyon',
#  'model_name_Colorado',
#  'model_name_D-Series',
#  'model_name_Dakota',
#  'model_name_El Camino',
#  'model_name_Explorer Sport Trac',
#  'model_name_F-150',
#  'model_name_F-150 Heritage',
#  'model_name_F-250',
#  'model_name_F-350',
#  'model_name_F-450',
#  'model_name_Frontier',
#  'model_name_GMT-400',
#  'model_name_Gladiator',
#  'model_name_H3T',
#  'model_name_Mark LT',
#  'model_name_Pick-Up',
#  'model_name_Raider',
#  'model_name_Ram',
#  'model_name_Ranger',
# ...

# %%
full_feature_list
# Out:
# ['model_ID',
#  'model_year',
#  'mileage',
#  'engine_cylinders',
#  'body_class_suv',
#  'body_class_truck',
#  'brand_name_ALFA ROMEO',
#  'brand_name_ASTON MARTIN',
#  'brand_name_AUDI',
#  'brand_name_BENTLEY',
#  'brand_name_BMW',
#  'brand_name_BUICK',
#  'brand_name_CADILLAC',
#  'brand_name_CHEVROLET',
#  'brand_name_CHRYSLER',
#  'brand_name_DODGE',
#  'brand_name_FIAT',
#  'brand_name_FORD',
#  'brand_name_GENESIS',
#  'brand_name_GMC',
#  'brand_name_HONDA',
#  'brand_name_HUMMER',
#  'brand_name_HYUNDAI',
#  'brand_name_INFINITI',
#  'brand_name_ISUZU',
#  'brand_name_JAGUAR',
#  'brand_name_JEEP',
#  'brand_name_KIA',
#  'brand_name_LAND ROVER',
#  'brand_name_LEXUS',
#  'brand_name_LINCOLN',
#  'brand_name_MASERATI',
#  'brand_name_MAZDA',
#  'brand_name_MERCEDES-BENZ',
#  'brand_name_MERCURY',
#  'brand_name_MINI',
#  'brand_name_MITSUBISHI',
#  'brand_name_NISSAN',
#  'brand_name_OLDSMOBILE',
#  'brand_name_PONTIAC',
#  'brand_name_PORSCHE',
#  'brand_name_RAM',
# ...

# %%
sedan_df.head(1)
# Out:
#   body_class brand_name model_name  model_ID  model_year  mileage  ask_price  \
# 0      sedan       FORD     Taurus    1782.0      2015.0    67588      16462
#
#     msrp                  color  engine_cylinders fuel_type_primary  \
# 0  16462  Ingot Silver Metallic               6.0          Gasoline
#
#                                                  vin
# 0  85384fd9108f6e9c75d7a538e4ce8a892170f7dbf42264...

# %%
sedan_feature_list
# Out:
# ['model_ID',
#  'model_year',
#  'mileage',
#  'engine_cylinders',
#  'brand_name_ALFA ROMEO',
#  'brand_name_ASTON MARTIN',
#  'brand_name_AUDI',
#  'brand_name_BENTLEY',
#  'brand_name_BMW',
#  'brand_name_BUICK',
#  'brand_name_CADILLAC',
#  'brand_name_CHEVROLET',
#  'brand_name_CHRYSLER',
#  'brand_name_DODGE',
#  'brand_name_FORD',
#  'brand_name_GENESIS',
#  'brand_name_HONDA',
#  'brand_name_HYUNDAI',
#  'brand_name_INFINITI',
#  'brand_name_JAGUAR',
#  'brand_name_KIA',
#  'brand_name_LEXUS',
#  'brand_name_LINCOLN',
#  'brand_name_MASERATI',
#  'brand_name_MAZDA',
#  'brand_name_MERCEDES-BENZ',
#  'brand_name_MERCURY',
#  'brand_name_MITSUBISHI',
#  'brand_name_NISSAN',
#  'brand_name_OLDSMOBILE',
#  'brand_name_PONTIAC',
#  'brand_name_PORSCHE',
#  'brand_name_SATURN',
#  'brand_name_SUBARU',
#  'brand_name_TOYOTA',
#  'brand_name_VOLKSWAGEN',
#  'brand_name_VOLVO',
#  'model_name_300',
#  'model_name_300C',
#  'model_name_320i',
#  'model_name_323i',
# ...

# %%
user_data = {
#     'model_ID':request.form['model_ID'],
    'model_year':'1982',
    'mileage':'123456',
    'engine_cylinders':'6',
    'make':'HONDA', 
    'model':'Civic',
    'fuel_type_primary':'Gasoline', 
}
# model_ID = user_data['model_ID']
model_year = user_data['model_year']
mileage = user_data['mileage']
engine_cylinders = user_data['engine_cylinders']
make = user_data['make']
model = user_data['model']
fuel_type_primary = user_data['fuel_type_primary']

# %% [markdown]
# Assemble full feature list, assemble full feature list with user data, pass to model

# %% [markdown]
# the user values will return a number - milage, model year, engine cylinder will return value higher than 1
# all models, makes/brands fuel type will be 1, everything not retuen from user will equal 0

# %%
test_submission = []
user_list = [model_year, mileage, engine_cylinders, make, model, fuel_type_primary]

# %%
for i, feature in enumerate(feature_list):
    print(f'index position: {i} - {feature}')
# Out:
# index position: 0 - model_ID
# index position: 1 - model_year
# index position: 2 - mileage
# index position: 3 - engine_cylinders
# index position: 4 - brand_name_ALFA ROMEO
# index position: 5 - brand_name_ASTON MARTIN
# index position: 6 - brand_name_AUDI
# index position: 7 - brand_name_BENTLEY
# index position: 8 - brand_name_BMW
# index position: 9 - brand_name_BUICK
# index position: 10 - brand_name_CADILLAC
# index position: 11 - brand_name_CHEVROLET
# index position: 12 - brand_name_CHRYSLER
# index position: 13 - brand_name_DODGE
# index position: 14 - brand_name_FORD
# index position: 15 - brand_name_GENESIS
# index position: 16 - brand_name_HONDA
# index position: 17 - brand_name_HYUNDAI
# index position: 18 - brand_name_INFINITI
# index position: 19 - brand_name_JAGUAR
# index position: 20 - brand_name_KIA
# index position: 21 - brand_name_LEXUS
# index position: 22 - brand_name_LINCOLN
# index position: 23 - brand_name_MASERATI
# index position: 24 - brand_name_MAZDA
# ...

# %%
model_name_list = list(model_name_list)

# %%
model_name_list.sort()

# %%
model_name_list = model_name_list[1:]

# %%
model_name_list = sedan_df['model_name'].unique()
model_ID_list = sedan_df['model_ID'].unique()


for i, element in enumerate(model_name_list):
    print(f"'{model_name_list[i]}' : {model_ID_list[i]},")
# Out:
# 'Taurus' : 1782.0,
# '300' : 1878.0,
# 'MKZ' : 1790.0,
# 'Fiesta' : 3267.0,
# 'G37' : 2337.0,
# 'LaCrosse' : 1821.0,
# 'Altima' : 1904.0,
# 'Malibu' : 1834.0,
# 'Fusion' : 1780.0,
# '320i' : 2172.0,
# 'Impala' : 1833.0,
# 'Focus' : 1779.0,
# '200' : 2053.0,
# 'Camry' : 2469.0,
# 'Passat' : 3134.0,
# 'Accord' : 1861.0,
# 'Mazda6' : 2078.0,
# 'Mazda3' : 2074.0,
# 'S6' : 3677.0,
# 'S60' : 1959.0,
# 'Cruze' : 1832.0,
# 'XJ' : 2242.0,
# 'Charger' : 1895.0,
# 'XTS' : 1827.0,
# 'ATS' : 1824.0,
# 'Maxima' : 2302.0,
# 'Milan' : 1793.0,
# 'MKS' : 1794.0,
# 'Continental' : 5192.0,
# 'Sonic' : 1835.0,
# 'Accent' : 2773.0,
# 'Sentra' : 1907.0,
# 'Verano' : 1823.0,
# 'Forte' : 2462.0,
# 'Dart' : 2054.0,
# 'Avenger' : 1892.0,
# 'Optima' : 2739.0,
# 'Corolla' : 2208.0,
# 'Civic' : 1863.0,
# 'Versa' : 1894.0,
# 'C-Class' : 2085.0,
# '300C' : 25754.0,
# 'Sonata' : 2459.0,
# 'Elantra' : 2735.0,
# 'Lucerne' : 4267.0,
# 'Challenger' : 1893.0,
# 'Jetta' : 3137.0,
# 'CTS' : 1825.0,
# 'WRX' : 2237.0,
# ...

# %%
for i, element in enumerate(model_name_list):
    # feature index location - model name - model ID
    print(f"'{i+37}' : ['{element}',{sedan_model_dict[f'{element}']}],")
# Out:
# '37' : ['300',1878.0],
# '38' : ['300C',25754.0],
# '39' : ['320i',2172.0],
# '40' : ['323i',13438.0],
# '41' : ['325i',1732.0],
# '42' : ['325xi',5195.0],
# '43' : ['328d',2220.0],
# '44' : ['328i',1709.0],
# '45' : ['328xi',2378.0],
# '46' : ['330e',2584.0],
# '47' : ['330i',1731.0],
# '48' : ['330xi',4308.0],
# '49' : ['335',14345.0],
# '50' : ['335d',1727.0],
# '51' : ['335i',1711.0],
# '52' : ['335xi',2357.0],
# '53' : ['340i',2231.0],
# '54' : ['428i',1870.0],
# '55' : ['430i',13798.0],
# '56' : ['435i',2230.0],
# '57' : ['440i',1729.0],
# '58' : ['525i',21790.0],
# '59' : ['525iA',2368.0],
# '60' : ['525xi',2313.0],
# '61' : ['528i',1715.0],
# '62' : ['528xi',2149.0],
# '63' : ['530e',1713.0],
# '64' : ['530i',2585.0],
# '65' : ['530iA',9115.0],
# '66' : ['530xi',2377.0],
# '67' : ['535d',2173.0],
# '68' : ['535i',1716.0],
# '69' : ['535i/535is',1688.0],
# '70' : ['535xi',2306.0],
# '71' : ['540i',24879.0],
# '72' : ['545i',8838.0],
# '73' : ['550i',1718.0],
# ...

# %%
sedan_model_dict = {
# ML_model feature # - model name - model_ID
'37' : ['300',1878.0],
'38' : ['300C',25754.0],
'39' : ['320i',2172.0],
'40' : ['323i',13438.0],
'41' : ['325i',1732.0],
'42' : ['325xi',5195.0],
'43' : ['328d',2220.0],
'44' : ['328i',1709.0],
'45' : ['328xi',2378.0],
'46' : ['330e',2584.0],
'47' : ['330i',1731.0],
'48' : ['330xi',4308.0],
'49' : ['335',14345.0],
'50' : ['335d',1727.0],
'51' : ['335i',1711.0],
'52' : ['335xi',2357.0],
'53' : ['340i',2231.0],
'54' : ['428i',1870.0],
'55' : ['430i',13798.0],
'56' : ['435i',2230.0],
'57' : ['440i',1729.0],
'58' : ['525i',21790.0],
'59' : ['525iA',2368.0],
'60' : ['525xi',2313.0],
'61' : ['528i',1715.0],
'62' : ['528xi',2149.0],
'63' : ['530e',1713.0],
'64' : ['530i',2585.0],
'65' : ['530iA',9115.0],
'66' : ['530xi',2377.0],
'67' : ['535d',2173.0],
'68' : ['535i',1716.0],
'69' : ['535i/535is',1688.0],
'70' : ['535xi',2306.0],
'71' : ['540i',24879.0],
'72' : ['545i',8838.0],
'73' : ['550i',1718.0],
'74' : ['626',6093.0],
'75' : ['640i',20813.0],
'76' : ['640xi',2038.0],
'77' : ['650i',2774.0],
'78' : ['650i / ALPINA B6',1699.0],
'79' : ['650i / B6',23521.0],
'80' : ['740Li',8702.0],
'81' : ['740i',2586.0],
'82' : ['740iL',2240.0],
'83' : ['745Li',1830.0],
'84' : ['750Li',1723.0],
'85' : ['750Li / ALPINA B7',21788.0],
'86' : ['750Lxi',1721.0],
'87' : ['750Lxi / ALPINA B7',21791.0],
'88' : ['750i',1722.0],
'89' : ['750i / ALPINA B7',13868.0],
'90' : ['750i / B7',9569.0],
'91' : ['750xi',16783.0],
'92' : ['750xi / ALPINA B7',9568.0],
'93' : ['A-Class',3151.0],
'94' : ['A3',3676.0],
'95' : ['A4',3146.0],
'96' : ['A6',3148.0],
'97' : ['A7',4015.0],
'98' : ['A8',13827.0],
'99' : ['ATS',1824.0],
'100' : ['Accent',2773.0],
'101' : ['Accord',1861.0],
'102' : ['ActiveHybrid 5',2587.0],
'103' : ['Alero',5063.0],
'104' : ['Altima',1904.0],
'105' : ['Amanti',2776.0],
'106' : ['Arteon',9091.0],
'107' : ['Aura',4336.0],
'108' : ['Avalon',2465.0],
'109' : ['Avenger',1892.0],
'110' : ['Aveo',5880.0],
'111' : ['Azera',26088.0],
'112' : ['Bonneville',2307.0],
'113' : ['Brooklands',20814.0],
'114' : ['Brougham',8852.0],
'115' : ['C-Class',2085.0],
'116' : ['C-HR',2778.0],
'117' : ['CC',8121.0],
'118' : ['CLA-Class',2083.0],
'119' : ['CLS-Class',2082.0],
'120' : ['CT6',10297.0],
'121' : ['CTS',1825.0],
'122' : ['Cadenza',3071.0],
'123' : ['Camry',2469.0],
'124' : ['Caprice',8840.0],
'125' : ['Caprice Police Vehicle',25134.0],
'126' : ['Cavalier',3184.0],
'127' : ['Challenger',1893.0],
'128' : ['Charger',1895.0],
'129' : ['Cirrus',5471.0],
'130' : ['Civic',1863.0],
'131' : ['Cobalt',4234.0],
'132' : ['Concorde',4259.0],
'133' : ['Concorde/LHS',14185.0],
'134' : ['Continental',5192.0],
'135' : ['Corolla',2208.0],
'136' : ['Corolla Matrix',2466.0],
'137' : ['Corsica',5181.0],
'138' : ['Cougar',5191.0],
'139' : ['Crown Victoria',21787.0],
'140' : ['Cruze',1832.0],
'141' : ['DTS',2764.0],
'142' : ['Dart',2054.0],
'143' : ['Deville',8844.0],
'144' : ['E-Class',2081.0],
'145' : ['ES',2475.0],
'146' : ['Echo',5410.0],
'147' : ['Elantra',2735.0],
'148' : ['Equus',1903.0],
'149' : ['Escort',3531.0],
'150' : ['Fiesta',3267.0],
'151' : ['Five Hundred',2347.0],
'152' : ['Fleetwood',9122.0],
'153' : ['Focus',1779.0],
'154' : ['Forte',2462.0],
'155' : ['Fusion',1780.0],
'156' : ['G25',2358.0],
'157' : ['G35',2305.0],
'158' : ['G37',2337.0],
'159' : ['G5',10997.0],
'160' : ['G6',4263.0],
'161' : ['G70',26481.0],
'162' : ['G8',4264.0],
'163' : ['G80',17213.0],
'164' : ['G90',12580.0],
'165' : ['GLI',5499.0],
'166' : ['GS',2180.0],
'167' : ['Genesis',1778.0],
'168' : ['Geo Prizm',5875.0],
'169' : ['Ghibli',11445.0],
'170' : ['Giulia (952)',10326.0],
'171' : ['Grand AM',9788.0],
'172' : ['Grand Marquis',1792.0],
'173' : ['Grand Prix',4262.0],
'174' : ['HS',3185.0],
'175' : ['I30',1720.0],
'176' : ['I35',25871.0],
'177' : ['ILX',2150.0],
'178' : ['IS',2184.0],
'179' : ['Impala',1833.0],
'180' : ['Impala Limited',13634.0],
'181' : ['Impreza',2235.0],
'182' : ['Insight',2777.0],
'183' : ['Integra',8842.0],
'184' : ['Intrepid',3675.0],
'185' : ['Ion',5879.0],
'186' : ['Jetta',3137.0],
'187' : ['K900',5347.0],
'188' : ['L300',9822.0],
'189' : ['LHS',5253.0],
'190' : ['LS',2182.0],
'191' : ['LS1',5343.0],
'192' : ['LaCrosse',1821.0],
'193' : ['LeSabre',3135.0],
'194' : ['Legacy',2232.0],
'195' : ['Lucerne',4267.0],
'196' : ['M3',1710.0],
'197' : ['M340i',13828.0],
'198' : ['M35',1730.0],
'199' : ['M35h',9452.0],
'200' : ['M37',2376.0],
'201' : ['M45',24944.0],
'202' : ['M5',2024.0],
'203' : ['M550i',3051.0],
'204' : ['M56',2356.0],
'205' : ['M6',2366.0],
'206' : ['MKS',1794.0],
'207' : ['MKZ',1790.0],
'208' : ['Malibu',1834.0],
'209' : ['Malibu Classic',1876.0],
'210' : ['Marauder',6475.0],
'211' : ['Mark',9787.0],
'212' : ['Maxima',2302.0],
'213' : ['Mazda3',2074.0],
'214' : ['Mazda6',2078.0],
'215' : ['Milan',1793.0],
'216' : ['Mirage G4',13842.0],
'217' : ['Montego',21792.0],
'218' : ['Mulsanne',8475.0],
'219' : ['Neon',8834.0],
'220' : ['Ninety Eight (98)',3650.0],
'221' : ['Optima',2739.0],
'222' : ['PRIUS',2209.0],
'223' : ['Panamera',7994.0],
'224' : ['Passat',3134.0],
'225' : ['Phaeton',6794.0],
'226' : ['Protege',9116.0],
'227' : ['Q50',1901.0],
'228' : ['Q70',5813.0],
'229' : ['Q70L',10208.0],
'230' : ['Quattroporte',2367.0],
'231' : ['RL',1872.0],
'232' : ['RLX',12579.0],
'233' : ['RS3',2765.0],
'234' : ['RS4',2298.0],
'235' : ['RS7',21793.0],
'236' : ['Rapide',14175.0],
'237' : ['Regal',1822.0],
'238' : ['Rio',2299.0],
'239' : ['S-Class',2086.0],
'240' : ['S3',8173.0],
'241' : ['S4',3147.0],
'242' : ['S40',3127.0],
'243' : ['S6',3677.0],
'244' : ['S60',1959.0],
'245' : ['S60 Cross Country',4781.0],
'246' : ['S7',8258.0],
'247' : ['S8',3678.0],
'248' : ['S80',1960.0],
'249' : ['S90',1728.0],
'250' : ['SS',1837.0],
'251' : ['STS',4300.0],
'252' : ['SVX',8955.0],
'253' : ['Sable',2365.0],
'254' : ['Scion iA',13603.0],
'255' : ['Sebring',1877.0],
'256' : ['Sentra',1907.0],
'257' : ['Seville',1828.0],
'258' : ['Sonata',2459.0],
'259' : ['Sonic',1835.0],
'260' : ['Spectra',8685.0],
'261' : ['Stratus',5500.0],
'262' : ['TL',1873.0],
'263' : ['TLX',5354.0],
'264' : ['TSX',1874.0],
'265' : ['Taurus',1782.0],
'266' : ['Town Car',1791.0],
'267' : ['Veloster',17528.0],
'268' : ['Verano',1823.0],
'269' : ['Versa',1894.0],
'270' : ['WRX',2237.0],
'271' : ['X-Type',2056.0],
'272' : ['XE',11440.0],
'273' : ['XF',2285.0],
'274' : ['XJ',2242.0],
'275' : ['XTS',1827.0],
'276' : ['Yaris',2464.0],
'277' : ['Yaris iA',24949.0],
'278' : ['Zephyr',2771.0],
'279' : ['new Passat',5878.0],}

# %%
user_return = request.form['model']
model_ID = sedan_model_dict['user_return'][1]
# Out:
# ['300', 1878.0]

# %%
model_ID = sedan_model_dict['37'][1]
model_ID
# Out:
# 1878.0

# %% [markdown]
#  <option value = "19">LINCOLN</option>

# %%
for i, element in enumerate(sedan_feature_list[37:-1]):
    model_name = element.split("_")[-1]

    print(f'<option value = "{i+37}"> {model_name}</option>')
# Out:
# <option value = "37"> 300</option>
# <option value = "38"> 300C</option>
# <option value = "39"> 320i</option>
# <option value = "40"> 323i</option>
# <option value = "41"> 325i</option>
# <option value = "42"> 325xi</option>
# <option value = "43"> 328d</option>
# <option value = "44"> 328i</option>
# <option value = "45"> 328xi</option>
# <option value = "46"> 330e</option>
# <option value = "47"> 330i</option>
# <option value = "48"> 330xi</option>
# <option value = "49"> 335</option>
# <option value = "50"> 335d</option>
# <option value = "51"> 335i</option>
# <option value = "52"> 335xi</option>
# <option value = "53"> 340i</option>
# <option value = "54"> 428i</option>
# <option value = "55"> 430i</option>
# <option value = "56"> 435i</option>
# <option value = "57"> 440i</option>
# <option value = "58"> 525i</option>
# <option value = "59"> 525iA</option>
# <option value = "60"> 525xi</option>
# <option value = "61"> 528i</option>
# <option value = "62"> 528xi</option>
# ...

# %%
test_var = sedan_feature_list[37]
model_name = test_var.split("_")[-1]
model_name
# Out:
# '300'

# %%
for i, element in enumerate(sedan_feature_list[4:37]):
    brand_name = element.split("_")[-1]

    print(f'<option value = "{i+4}"> {brand_name}</option>')
# Out:
# <option value = "4"> ALFA ROMEO</option>
# <option value = "5"> ASTON MARTIN</option>
# <option value = "6"> AUDI</option>
# <option value = "7"> BENTLEY</option>
# <option value = "8"> BMW</option>
# <option value = "9"> BUICK</option>
# <option value = "10"> CADILLAC</option>
# <option value = "11"> CHEVROLET</option>
# <option value = "12"> CHRYSLER</option>
# <option value = "13"> DODGE</option>
# <option value = "14"> FORD</option>
# <option value = "15"> GENESIS</option>
# <option value = "16"> HONDA</option>
# <option value = "17"> HYUNDAI</option>
# <option value = "18"> INFINITI</option>
# <option value = "19"> JAGUAR</option>
# <option value = "20"> KIA</option>
# <option value = "21"> LEXUS</option>
# <option value = "22"> LINCOLN</option>
# <option value = "23"> MASERATI</option>
# <option value = "24"> MAZDA</option>
# <option value = "25"> MERCEDES-BENZ</option>
# <option value = "26"> MERCURY</option>
# <option value = "27"> MITSUBISHI</option>
# ...

# %%
sedan_feature_list[4:37]
# Out:
# ['brand_name_ALFA ROMEO',
#  'brand_name_ASTON MARTIN',
#  'brand_name_AUDI',
#  'brand_name_BENTLEY',
#  'brand_name_BMW',
#  'brand_name_BUICK',
#  'brand_name_CADILLAC',
#  'brand_name_CHEVROLET',
#  'brand_name_CHRYSLER',
#  'brand_name_DODGE',
#  'brand_name_FORD',
#  'brand_name_GENESIS',
#  'brand_name_HONDA',
#  'brand_name_HYUNDAI',
#  'brand_name_INFINITI',
#  'brand_name_JAGUAR',
#  'brand_name_KIA',
#  'brand_name_LEXUS',
#  'brand_name_LINCOLN',
#  'brand_name_MASERATI',
#  'brand_name_MAZDA',
#  'brand_name_MERCEDES-BENZ',
#  'brand_name_MERCURY',
#  'brand_name_MITSUBISHI',
#  'brand_name_NISSAN',
#  'brand_name_OLDSMOBILE',
#  'brand_name_PONTIAC',
#  'brand_name_PORSCHE',
#  'brand_name_SATURN',
#  'brand_name_SUBARU',
#  'brand_name_TOYOTA',
#  'brand_name_VOLKSWAGEN',
#  'brand_name_VOLVO']

# %%
sedan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138318 entries, 0 to 138317
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   body_class         138318 non-null  object
#  1   brand_name         138318 non-null  object
#  2   model_name         138318 non-null  object
#  3   model_ID           138318 non-null  float64
#  4   model_year         138318 non-null  float64
#  5   mileage            138318 non-null  int64
#  6   ask_price          138318 non-null  int64
#  7   msrp               138318 non-null  int64
#  8   color              138318 non-null  object
#  9   engine_cylinders   138318 non-null  float64
#  10  fuel_type_primary  138318 non-null  object
#  11  vin                138318 non-null  object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 12.7+ MB

# %%
prediction = 17054.12456

# %%
prediction = "${0:,.2f}".format(prediction)

# %%
prediction
# Out:
# '$17,054.12'

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
