# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
trucks = 'csv/PICKUP_DATA_CLEAN.csv'
sedan = 'csv/SEDAN_DATA_CLEAN.csv'
suv = 'csv/SUV_DATA_CLEAN.csv'

# %%
trucks_df = pd.read_csv(trucks)
sedan_df = pd.read_csv(sedan)
suv_df = pd.read_csv(suv)

# %%
df_list = [trucks_df, sedan_df, suv_df]

# %%
full_df = pd.concat(df_list)

# %%
full_df.to_csv()
# Out:
#          brandName          modelName  vf_ModelID  vf_ModelYear  mileage  \
# 0             FORD              F-250      1805.0        2017.0    19106
# 1             FORD              F-150      1801.0        2017.0    28194
# 2              GMC             Sierra      1857.0        2017.0     7483
# 3             FORD              F-250      1805.0        2017.0    23881
# 4              GMC             Canyon      4093.0        2017.0     6333
# ...            ...                ...         ...           ...      ...
# 139639  LAND ROVER        Range Rover      2247.0        2016.0    45505
# 139640  LAND ROVER  Range Rover Sport      2246.0        2016.0    27160
# 139641        FORD           Explorer      1800.0        2014.0    94105
# 139642       HONDA               CR-V      1865.0        2016.0    30011
# 139643       HONDA               CR-V      1865.0        2007.0   202802
#
#         askPrice   msrp                      color  vf_EngineCylinders  \
# 0          40962  40962      Ingot Silver Metallic                 8.0
# 1          28962  28962      Ingot Silver Metallic                 6.0
# 2          43962  43962       Crimson Red Tintcoat                 8.0
# 3          38962  38962               Oxford White                 8.0
# 4          30962  30962                 Onyx Black                 6.0
# ...          ...    ...                        ...                 ...
# 139639     52001  57807            Santorini Black                 8.0
# 139640     41106  47105                 Fuji White                 6.0
# 139641     15958  15958           Deep Impact Blue                 6.0
# 139642     23000  23000  Alabaster Silver Metallic                 4.0
# 139643      8500   8500                  Green Tea                 4.0
#
#        vf_FuelTypePrimary                                                vin
# 0                  Diesel  bcd4bbecbba3b9ed2330d543abc3d90b997aa8fa6e628d...
# 1                Gasoline  a8f09496d9523e33ee3a8f885a475f5ef001d68a334c98...
# 2                Gasoline  c65dd3e96f4f68a0d4c7b09005273e0312295057c7c529...
# 3                  Diesel  966168515802a7cf510d6c87a15cf71cc4385316a504c6...
# 4                Gasoline  9c7648c843035d0b46e9d716d947dfa3d0e8881054247a...
# ...                   ...                                                ...
# 139639           Gasoline  bd83ff980b3313756030134da70c944d6646d342386ba0...
# 139640           Gasoline  726c69b62e6bd812524cf484e83fb8faaf766021658546...
# 139641           Gasoline  ad650ca3c8e6011a5275c48c294ef8dbad12b865727975...
# 139642           Gasoline  febf2e0813355a89ade171c6983c848db7b960d3881f16...
# 139643           Gasoline  a42d6bd42c029757ee15a09da3c657e217f44e04fd0f55...
#
# [328750 rows x 11 columns]
